# %% [markdown]
# ## Google image downloader
# - https://github.com/hardikvasa/google-images-download

# %%
# !pip install google_images_download

# %%
from google_images_download import google_images_download
import ssl  # ssl Error 발생 시
ssl._create_default_https_context = ssl._create_unverified_context

# %%
def imageCrawling(keyword, dir):
    response = google_images_download.googleimagesdownload()
 
    arguments = {"keywords":keyword,      # 검색 키워드
                 "limit":100,             # 크롤링 이미지 수
                 "print_urls":False,       # 이미지 url 출력
                 "no_directory":True,     # 
                 'output_directory':dir}  # 크롤링 이미지를 저장할 폴더
 
    paths = response.download(arguments)
    print(paths)

imageCrawling('tomato image','./cnn_sample/cnn_sample/crawling')
# Out:
# Item no.: 1 --> Item name = tomato image
# Evaluating...
# Starting Download...
# Completed Image ====> 1.tomatoes_c_Kanawa_Studio-iStock-GettyImages-1163317374-LEDE.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 2.Solanum_MountainMerit_BonniePlants_v2.jpg
# Invalid or missing image format. Skipping...
# Invalid or missing image format. Skipping...
# Completed Image ====> 3.Cherry-Tomato_grande.jpg
# Completed Image ====> 4.tomatoes-1296x728-feature.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 5.1371616351150.jpeg
# Completed Image ====> 6.tomato.jpg
# Completed Image ====> 7.tomato-isolated-fresh-clipping-path-260nw-714979129.jpg
# Completed Image ====> 8.capture-2.png
# Completed Image ====> 9.Bright_red_tomato_and_cross_section02-1.jpg
# Completed Image ====> 10.tomatoes_helios4eos_gettyimages-edit.jpeg
# Completed Image ====> 11.Tomato-Shimla.jpg
# Completed Image ====> 12.tomato.jpg
# ...

# %%
imageCrawling('안익은 토마토','C:/Users/202-018/Anaconda_src/cnn_sample/green/')
# Out:
# Item no.: 1 --> Item name = \uc548\uc775\uc740 \ud1a0\ub9c8\ud1a0
# Evaluating...
# Starting Download...
# Completed Image ====> 1.9b4fa6e584a3454d9d8f05cce2054783.JPG
# Completed Image ====> 2.29tomato1-superJumbo.jpg
# Completed Image ====> 3.IMG_794723243.JPG
# Completed Image ====> 4.istock_000048931678_medium-e1461001862773.jpg
# Completed Image ====> 5.%B4%FA%C0%CD%C0%BA_%C5%E4%B8%B6%C5%E4.JPG
# Invalid or missing image format. Skipping...
# Invalid or missing image format. Skipping...
# Completed Image ====> 6.exim_01-25022215.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 7.57622_167440_315.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 8.hqdefault.jpg
# Completed Image ====> 9.12.jpg
# Completed Image ====> 10.maxresdefault.jpg
# Invalid or missing image format. Skipping...
# Invalid or missing image format. Skipping...
# Completed Image ====> 11.maxresdefault.jpg
# Completed Image ====> 12.DSC_0014.JPG
# ...
